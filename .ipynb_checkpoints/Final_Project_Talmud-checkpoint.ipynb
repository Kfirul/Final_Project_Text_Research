# %% [markdown]
# # Imports

# %%
import warnings
warnings.filterwarnings('ignore')
import scrapy
from scrapy.crawler import CrawlerProcess
import re
import pandas as pd
from urllib.parse import urlparse, parse_qs, urlencode, urlunparse

# %% [markdown]
# # Translation

# %%
# Define the LAT_TO_HEB dictionary
LAT_TO_HEB = {
    ')': 'א',
    'b': 'ב',
    'g': 'ג',
    'd': 'ד',
    'h': 'ה',
    'w': 'ו',
    'z': 'ז',
    'x': 'ח',
    'T': 'ט',
    'y': 'י',
    'k': 'כ',
    'K': 'ך',
    'l': 'ל',
    'm': 'מ',
    'M': 'ם',
    'n': 'נ',
    'N': 'ן',
    's': 'ס',
    '(': 'ע',
    'p': 'פ',
    'P': 'ף',
    'c': 'צ',
    'C': 'ץ',
    'q': 'ק',
    'r': 'ר',
    '$': 'ש',
    '&': 'שׂ',
    't': 'ת',
    '"': '',
    '^': '',
}

# Function to replace Latin characters with Hebrew
def replace_with_heb_chars(word: str) -> str:
    return ''.join(LAT_TO_HEB.get(char, char) for char in word)

def lat_to_heb(st: str) -> str:
    words = st.split()
    heb_words = [replace_with_heb_chars(word) for word in words]
    return ' '.join(heb_words)

# Define all the transformation functions
def replace_sub(orig_str: str, start: int, end: int, replacement: str) -> str:
    return orig_str[:start] + replacement + orig_str[end + 1:]

def r3_slash_slash2(st: str) -> str:
    cont1 = r"(?P<cont1>\\[^/]+|[^/ ]+)"
    cont2 = r"(?P<cont2>[^/]*/)"
    return re.sub(rf"{cont1}\s*/{cont2}", '\g<cont2>', st)

def r3_slash_slash(st: str) -> str:
    r3 = re.compile(r'(cont) "/" (cont) "/"')
    matches = r3.finditer(st)
    if not matches:
        return st
    new_st = st
    for match in reversed(list(matches)):
        start = match.start()
        end = match.end()
        new_st = replace_sub(
            new_st,
            start,
            end - 1,
            new_st[match.start(1): match.end(1)]
        )
    return new_st

def r_5_4_hash_hash(st: str) -> str:
    return re.sub(r'#[^#]*#', '', st)

def r2_squigglie_slash_slash(st: str) -> str:
    return re.sub(r'"/"', '', st)

def r11_double_squiggles(st: str) -> str:
    return re.sub(r'\{\{|\}\}', '', st)

def r12_14_question(st: str) -> str:
    return re.sub(r'\?', '', st)

def r1_squiggles(st: str) -> str:
    return re.sub(r'\{[^{}]*\}', '', st)

def r6_quotes(st: str) -> str:
    # Remove all substrings enclosed in double quotes
    return re.sub(r'"[^"]*"', '', st)

def r8_7_dots(st: str) -> str:
    return re.sub(r'\.{2,}', '', st)

def r9_chevrons(st: str) -> str:
    return re.sub(r'[<>]', '', st)

def r10_carets(st: str) -> str:
    return re.sub(r'\^[^^]*\^', '', st)

def r13_backslash(st: str) -> str:
    return st.replace('\\', '')

def r15_caret(st: str) -> str:
    return re.sub(r'\^', '', st)

def r16_comma(st: str) -> str:
    return re.sub(r',', '', st)

def r17_plus(st: str) -> str:
    return re.sub(r'\+', '', st)

def r18_at_equals_dash(st: str) -> str:
    return st.replace('@', ' ').replace('=', '').replace('-', '')

def r19_squiggle_space(st: str) -> str:
    return st.replace('{ ', ' ')

def r20_remove_braces(st: str) -> str:
    return st.replace('[', '').replace(']', '')

def r21_remove_bang(st: str) -> str:
    return st.replace('!', '')

def r22_backtick_to_space(st: str) -> str:
    return st.replace('`', ' ')

def r_WS(st: str) -> str:
    st = re.sub(r' +', ' ', st)
    st = st.strip()
    return st

def transform_str(st: str) -> str:
    st = lat_to_heb(st)  # Apply Latin to Hebrew transformation first
    rules = [
        r9_chevrons,
        r_5_4_hash_hash,
        r16_comma,
        r12_14_question,
        r10_carets,
        r15_caret,
        r17_plus,
        r8_7_dots,
        r3_slash_slash2,
        r6_quotes,
        r13_backslash,
        r2_squigglie_slash_slash,
        r11_double_squiggles,
        r1_squiggles,
        r18_at_equals_dash,
        r19_squiggle_space,
        r20_remove_braces,
        r21_remove_bang,
        r22_backtick_to_space,
        r_WS
    ]

    for f in rules:
        st = f(st)
    return st

def apply_transformation(df: pd.DataFrame, column_name: str) -> pd.DataFrame:
    df[f'{column_name}_transformed'] = df[column_name].apply(transform_str)
    return df

if __name__ == "__main__":
    # Create a sample DataFrame
    df_check = pd.DataFrame({'text': ['^tn)^', '"lytny"']})
    
    # Apply transformation
    df_check = apply_transformation(df_check, 'text')
    
    # Display the transformed DataFrame
df_check
# Out:
#       text text_transformed
# 0    ^tn)^              תנא
# 1  "lytny"            ליתני

# %% [markdown]
# # Sort

# %%
def replace_x_in_coord(url: str) -> str:
    # Parse the URL
    parsed_url = urlparse(url)
    query_params = parse_qs(parsed_url.query)
    
    # Get and modify the 'coord' parameter
    coord = query_params.get('coord', [''])[0]
    coord = coord.replace('x', '1')
    
    # Update query parameters
    query_params['coord'] = [coord]
    
    # Rebuild the URL with updated parameters
    new_query_string = urlencode(query_params, doseq=True)
    new_url = urlunparse((
        parsed_url.scheme,
        parsed_url.netloc,
        parsed_url.path,
        parsed_url.params,
        new_query_string,
        parsed_url.fragment
    ))
    
    return new_url

# %%
def sort_by_coord_and_word(df, url_column='url'):
    # Extract 'coord' and 'word' values using str.extract
    df[['coord', 'word']] = df[url_column].str.extract(r'coord=(\d+)&word=(\d+)')

    # Ignore the first 7 digits of 'coord', and handle NaN values by filling them with a placeholder
    df['coord'] = df['coord'].str[7:].fillna('0')
    df['word'] = df['word'].fillna('0')

    # Convert 'coord' and 'word' to integers for correct sorting
    df['coord'] = df['coord'].astype(int)
    df['word'] = df['word'].astype(int)

    # Sort by 'coord' and then by 'word'
    sorted_df = df.sort_values(by=['coord', 'word'], ascending=[True, True])

    # Drop the temporary columns 'coord' and 'word'
    sorted_df = sorted_df.drop(columns=['coord', 'word'])

    return sorted_df

# %% [markdown]
# # Data Process

# %%
def data_process(file_path): 
    
    # Read the JSON file into a DataFrame
    df = pd.read_json(file_path)

    # Apply transformation
    df = apply_transformation(df, 'text')

    # Apply the transformation
    df['url'] = df['url'].apply(replace_x_in_coord)

    # Assuming your DataFrame is named 'df' and has a column 'url'
    sorted_df = sort_by_coord_and_word(df)

    # Display the sorted DataFrame
    return sorted_df

# %% [markdown]
# # Convert to Dataframe

# %%
# Path to the JSON file
file_path = r'C:\Users\USER\Desktop\Final_Project\Data\Masekhet_ber.json'

# Read the JSON file into a DataFrame
df = pd.read_json(file_path)

# Display the DataFrame
df
# Out:
#            text                                    url  \
# 0           tn)  bablex.php?coord=7100101002115&word=0
# 1       "(rbyt"  bablex.php?coord=7100101002124&word=1
# 2         lytny  bablex.php?coord=7100101002124&word=0
# 3           tn)  bablex.php?coord=7100101002126&word=0
# 4           tn)  bablex.php?coord=7100101002125&word=1
# ...         ...                                    ...
# 17532      wtw;  bablex.php?coord=7100101002116&word=0
# 17533  "m)ymty"  bablex.php?coord=7100101002115&word=4
# 17534     dqtny  bablex.php?coord=7100101002115&word=3
# 17535       q)y  bablex.php?coord=7100101002115&word=2
# 17536    h^y^k)  bablex.php?coord=7100101002115&word=1
#
#                                                lexicon_0  \
# 0                            \n\n\ntn) noun sg. emphatic
# 1      there is no data for this word, it may be unde...
# 2                                       \n\n\ntny verb G
# 3                                       \n\n\ntny verb G
# 4                            \n\n\ntn) noun sg. emphatic
# ...                                                  ...
# 17532                                        \n\n\nw_ c
# 17533  there is no data for this word, it may be unde...
# 17534                         \n\n\nd_ c = d_ c --> dy c
# 17535                                   \n\n\nqwm verb G
# 17536                                      \n\n\nhyk) a
#
#                    lexicon_1 lexicon_2 lexicon_3  lexicon_4
# 0                       None      None      None        NaN
# 1                       None      None      None        NaN
# 2                       None      None      None        NaN
# 3                       None      None      None        NaN
# 4                       None      None      None        NaN
# ...                      ...       ...       ...        ...
# 17532  tw a = tw X --> twb X      None      None        NaN
# 17533                   None      None      None        NaN
# 17534             tny verb G      None      None        NaN
# 17535                   None      None      None        NaN
# 17536                   None      None      None        NaN
#
# [17537 rows x 7 columns]

# %%
# Count the number of None and NaN values in each column
null_counts = df.isnull().sum()

# Display the count of None and NaN values for each column
print(null_counts)
# Out:
# text             0
# url              0
# lexicon_0        0
# lexicon_1    14246
# lexicon_2    17490
# lexicon_3    17533
# lexicon_4    17537
# dtype: int64

# %%
# To check unique values in a specific column, e.g., 'text'
unique_values = df['lexicon_3'].unique()

# Display the unique values
print(unique_values)
# Out:
# [None 'Trz noun pl. emphatic' '(lm noun sg. emphatic'
#  'm(rb noun sg. emphatic']

# %%
# To check unique values in a specific column, e.g., 'text'
unique_values = df['lexicon_2'].unique()

# Display the unique values
print(unique_values)
# Out:
# [None ')tr) noun sg. abs. or construct' 'lyly) noun sg. emphatic'
#  'dr$ verb G' 'hyk) a' 'd(t) noun sg. emphatic' 'Twrzyn noun sg. emphatic'
#  '(lm noun sg. emphatic' '&m)l) noun sg. emphatic= &m)l N --> sm)l N'
#  '$lp verb G' 'hytyr) noun sg. emphatic'
#  'rbnn noun pl. emphatic= rbnn N --> rbn N' 'ry$@glwt) noun sg. emphatic'
#  'dyd_ P02' 'kl noun pl. construct' 'mTwy A02'
#  'non-Aramaic or fragmentary form' 'br noun pl. construct'
#  'rb noun sg. emphatic' 'hk P01' 'h) P01' 'lgby p01' ')mr verb G'
#  'ywm) noun pl. construct' 'qysr noun sg. abs. or construct'
#  '$bh noun sg. emphatic' '(bd verb G' 'c(r) noun sg. emphatic'
#  'tny verb C' 'tmrt) noun pl. emphatic' 'xmr) noun sg. emphatic'
#  '(l@krx_ p02']

# %% [markdown]
# # Translation

# %%
# Create a sample DataFrame
# df = pd.DataFrame({'text': ['tn)', 'lytny']})
    
# Apply transformation
df = apply_transformation(df, 'text')
    
# Display the transformed DataFrame
df
# Out:
#            text                                    url  \
# 0           tn)  bablex.php?coord=7100101002115&word=0
# 1       "(rbyt"  bablex.php?coord=7100101002124&word=1
# 2         lytny  bablex.php?coord=7100101002124&word=0
# 3           tn)  bablex.php?coord=7100101002126&word=0
# 4           tn)  bablex.php?coord=7100101002125&word=1
# ...         ...                                    ...
# 17532      wtw;  bablex.php?coord=7100101002116&word=0
# 17533  "m)ymty"  bablex.php?coord=7100101002115&word=4
# 17534     dqtny  bablex.php?coord=7100101002115&word=3
# 17535       q)y  bablex.php?coord=7100101002115&word=2
# 17536    h^y^k)  bablex.php?coord=7100101002115&word=1
#
#                                                lexicon_0  \
# 0                            \n\n\ntn) noun sg. emphatic
# 1      there is no data for this word, it may be unde...
# 2                                       \n\n\ntny verb G
# 3                                       \n\n\ntny verb G
# 4                            \n\n\ntn) noun sg. emphatic
# ...                                                  ...
# 17532                                        \n\n\nw_ c
# 17533  there is no data for this word, it may be unde...
# 17534                         \n\n\nd_ c = d_ c --> dy c
# 17535                                   \n\n\nqwm verb G
# 17536                                      \n\n\nhyk) a
#
#                    lexicon_1 lexicon_2 lexicon_3  lexicon_4 text_transformed
# 0                       None      None      None        NaN              תנא
# 1                       None      None      None        NaN            ערבית
# 2                       None      None      None        NaN            ליתני
# 3                       None      None      None        NaN              תנא
# 4                       None      None      None        NaN              תנא
# ...                      ...       ...       ...        ...              ...
# 17532  tw a = tw X --> twb X      None      None        NaN             ותו;
# 17533                   None      None      None        NaN           מאימתי
# 17534             tny verb G      None      None        NaN            דקתני
# 17535                   None      None      None        NaN              קאי
# 17536                   None      None      None        NaN             היכא
#
# [17537 rows x 8 columns]

# %%
# Apply the transformation
df['url'] = df['url'].apply(replace_x_in_coord)

# Assuming your DataFrame is named 'df' and has a column 'url'
sorted_df = sort_by_coord_and_word(df)

# Display the sorted DataFrame
sorted_df
# Out:
#            text                                    url  \
# 0           tn)  bablex.php?coord=7100101002115&word=0
# 17536    h^y^k)  bablex.php?coord=7100101002115&word=1
# 17535       q)y  bablex.php?coord=7100101002115&word=2
# 17534     dqtny  bablex.php?coord=7100101002115&word=3
# 17533  "m)ymty"  bablex.php?coord=7100101002115&word=4
# ...         ...                                    ...
# 365          l)  bablex.php?coord=7100101064109&word=3
# 364         qdM  bablex.php?coord=7100101064109&word=4
# 363      lbytyh  bablex.php?coord=7100101064109&word=5
# 362         drb  bablex.php?coord=7100101064109&word=6
# 361        ywsP  bablex.php?coord=7100101064109&word=7
#
#                                                lexicon_0  \
# 0                            \n\n\ntn) noun sg. emphatic
# 17536                                      \n\n\nhyk) a
# 17535                                   \n\n\nqwm verb G
# 17534                         \n\n\nd_ c = d_ c --> dy c
# 17533  there is no data for this word, it may be unde...
# ...                                                  ...
# 365                                          \n\n\nl) a
# 364                                     \n\n\nqdm verb G
# 363                                        \n\n\nl_ p03
# 362                           \n\n\nd_ p = d_ p --> dy p
# 361    there is no data for this word, it may be unde...
#
#                     lexicon_1 lexicon_2 lexicon_3  lexicon_4 text_transformed
# 0                        None      None      None        NaN              תנא
# 17536                    None      None      None        NaN             היכא
# 17535                    None      None      None        NaN              קאי
# 17534              tny verb G      None      None        NaN            דקתני
# 17533                    None      None      None        NaN           מאימתי
# ...                       ...       ...       ...        ...              ...
# 365                      None      None      None        NaN               לא
# 364                      None      None      None        NaN              קדם
# 363    byt) noun sg. emphatic      None      None        NaN           לביתיה
# 362      rb noun sg. emphatic      None      None        NaN              דרב
# 361                      None      None      None        NaN             יוסף
#
# [17537 rows x 8 columns]

# %%
# Count empty values in the specified column
empty_count = sorted_df['text_transformed'].isna().sum() + (sorted_df['text_transformed'] == '').sum()

print(f"Number of empty values in the column: {empty_count}")
# Out:
# Number of empty values in the column: 55

# %%
# Filter rows with empty values
empty_rows = sorted_df[sorted_df['text_transformed'].isna() | (sorted_df['text_transformed'] == '')]

# Print the empty rows
print("Rows where 'text_transformed' is empty:")
empty_rows
# Out:
# Rows where 'text_transformed' is empty:
#          text                                     url  \
# 17364   <...>   bablex.php?coord=7100101002232&word=5
# 16875    ..."   bablex.php?coord=7100101004237&word=3
# 16430    ..."  bablex.php?coord=7100101006152&word=13
# 16424    ..."  bablex.php?coord=7100101006152&word=18
# 16421    ..."  bablex.php?coord=7100101006152&word=22
# 16417    ..."  bablex.php?coord=7100101006152&word=27
# 16395    ..."   bablex.php?coord=7100101006154&word=4
# 16250    ..."  bablex.php?coord=7100101007122&word=16
# 15652    ..."   bablex.php?coord=7100101009138&word=2
# 15622    ..."  bablex.php?coord=7100101009140&word=22
# 15526    ..."   bablex.php?coord=7100101009253&word=7
# 15497    ..."   bablex.php?coord=7100101010110&word=8
# 15299    ..."   bablex.php?coord=7100101011103&word=9
# 13456    ..."  bablex.php?coord=7100101020108&word=13
# 13383       +   bablex.php?coord=7100101020121&word=1
# 12803    ..."   bablex.php?coord=7100101022206&word=5
# 10558    ..."  bablex.php?coord=7100101029155&word=10
# 9979     ..."  bablex.php?coord=7100101031246&word=10
# 9750     ..."   bablex.php?coord=7100101033236&word=2
# 9409        +   bablex.php?coord=7100101035239&word=7
# 9392     {{}}   bablex.php?coord=7100101035240&word=2
# 9026     ..."   bablex.php?coord=7100101036152&word=6
# 174      ..."   bablex.php?coord=7100101039121&word=2
# 6902     ..."   bablex.php?coord=7100101043252&word=2
# 6892     ..."   bablex.php?coord=7100101043254&word=2
# 6851   {sw)y}   bablex.php?coord=7100101044113&word=7
# 6696     ..."   bablex.php?coord=7100101044214&word=4
# 6657     ..."   bablex.php?coord=7100101044227&word=3
# 6620     ..."   bablex.php?coord=7100101044235&word=3
# 6592     ..."   bablex.php?coord=7100101044237&word=3
# 6075     {{}}   bablex.php?coord=7100101046233&word=4
# 5754     ..."  bablex.php?coord=7100101047252&word=11
# 5554     ..."   bablex.php?coord=7100101048129&word=5
# 5177     ..."   bablex.php?coord=7100101050141&word=2
# 4749     ..."   bablex.php?coord=7100101052210&word=3
# 3879     ..."   bablex.php?coord=7100101055117&word=9
# 282      ..."   bablex.php?coord=7100101056115&word=2
# 3323     ..."  bablex.php?coord=7100101056121&word=12
# 3234     ..."  bablex.php?coord=7100101056130&word=15
# 1172     ..."   bablex.php?coord=7100101060227&word=3
# 1138     ..."   bablex.php?coord=7100101060232&word=6
# 1134     ..."   bablex.php?coord=7100101060233&word=4
# 1162     ..."   bablex.php?coord=7100101060233&word=4
# 1157     ..."   bablex.php?coord=7100101060233&word=9
# 1126     ..."   bablex.php?coord=7100101060234&word=7
# 1097     ..."   bablex.php?coord=7100101060235&word=3
# 1106     ..."   bablex.php?coord=7100101060236&word=4
# 1101     ..."   bablex.php?coord=7100101060236&word=9
# 1121     ..."   bablex.php?coord=7100101060237&word=4
# 1151     ..."   bablex.php?coord=7100101060239&word=5
# 1146     ..."   bablex.php?coord=7100101060240&word=4
# 1115     ..."   bablex.php?coord=7100101060241&word=4
# 1111     ..."   bablex.php?coord=7100101060242&word=4
# 558      ..."  bablex.php?coord=7100101062224&word=15
# 550      ..."   bablex.php?coord=7100101062246&word=1
#
#                                                lexicon_0 lexicon_1 lexicon_2  \
# 17364  there is no data for this word, it may be unde...      None      None
# 16875  there is no data for this word, it may be unde...      None      None
# 16430  there is no data for this word, it may be unde...      None      None
# 16424  there is no data for this word, it may be unde...      None      None
# 16421  there is no data for this word, it may be unde...      None      None
# 16417  there is no data for this word, it may be unde...      None      None
# 16395  there is no data for this word, it may be unde...      None      None
# 16250  there is no data for this word, it may be unde...      None      None
# 15652  there is no data for this word, it may be unde...      None      None
# 15622  there is no data for this word, it may be unde...      None      None
# 15526  there is no data for this word, it may be unde...      None      None
# 15497  there is no data for this word, it may be unde...      None      None
# 15299  there is no data for this word, it may be unde...      None      None
# 13456  there is no data for this word, it may be unde...      None      None
# 13383  there is no data for this word, it may be unde...      None      None
# 12803  there is no data for this word, it may be unde...      None      None
# 10558  there is no data for this word, it may be unde...      None      None
# 9979   there is no data for this word, it may be unde...      None      None
# 9750   there is no data for this word, it may be unde...      None      None
# 9409   there is no data for this word, it may be unde...      None      None
# 9392   there is no data for this word, it may be unde...      None      None
# 9026   there is no data for this word, it may be unde...      None      None
# 174    there is no data for this word, it may be unde...      None      None
# 6902   there is no data for this word, it may be unde...      None      None
# 6892   there is no data for this word, it may be unde...      None      None
# 6851   there is no data for this word, it may be unde...      None      None
# 6696   there is no data for this word, it may be unde...      None      None
# 6657   there is no data for this word, it may be unde...      None      None
# 6620   there is no data for this word, it may be unde...      None      None
# 6592   there is no data for this word, it may be unde...      None      None
# 6075   there is no data for this word, it may be unde...      None      None
# 5754   there is no data for this word, it may be unde...      None      None
# 5554   there is no data for this word, it may be unde...      None      None
# 5177   there is no data for this word, it may be unde...      None      None
# 4749   there is no data for this word, it may be unde...      None      None
# 3879   there is no data for this word, it may be unde...      None      None
# 282    there is no data for this word, it may be unde...      None      None
# 3323   there is no data for this word, it may be unde...      None      None
# 3234   there is no data for this word, it may be unde...      None      None
# 1172   there is no data for this word, it may be unde...      None      None
# 1138   there is no data for this word, it may be unde...      None      None
# 1134   there is no data for this word, it may be unde...      None      None
# 1162   there is no data for this word, it may be unde...      None      None
# 1157   there is no data for this word, it may be unde...      None      None
# 1126   there is no data for this word, it may be unde...      None      None
# 1097   there is no data for this word, it may be unde...      None      None
# 1106   there is no data for this word, it may be unde...      None      None
# 1101   there is no data for this word, it may be unde...      None      None
# 1121   there is no data for this word, it may be unde...      None      None
# 1151   there is no data for this word, it may be unde...      None      None
# 1146   there is no data for this word, it may be unde...      None      None
# 1115   there is no data for this word, it may be unde...      None      None
# 1111   there is no data for this word, it may be unde...      None      None
# 558    there is no data for this word, it may be unde...      None      None
# 550    there is no data for this word, it may be unde...      None      None
#
#       lexicon_3  lexicon_4 text_transformed
# 17364      None        NaN
# 16875      None        NaN
# 16430      None        NaN
# 16424      None        NaN
# 16421      None        NaN
# 16417      None        NaN
# 16395      None        NaN
# 16250      None        NaN
# 15652      None        NaN
# 15622      None        NaN
# 15526      None        NaN
# 15497      None        NaN
# 15299      None        NaN
# 13456      None        NaN
# 13383      None        NaN
# 12803      None        NaN
# 10558      None        NaN
# 9979       None        NaN
# 9750       None        NaN
# 9409       None        NaN
# 9392       None        NaN
# 9026       None        NaN
# 174        None        NaN
# 6902       None        NaN
# 6892       None        NaN
# 6851       None        NaN
# 6696       None        NaN
# 6657       None        NaN
# 6620       None        NaN
# 6592       None        NaN
# 6075       None        NaN
# 5754       None        NaN
# 5554       None        NaN
# 5177       None        NaN
# 4749       None        NaN
# 3879       None        NaN
# 282        None        NaN
# 3323       None        NaN
# 3234       None        NaN
# 1172       None        NaN
# 1138       None        NaN
# 1134       None        NaN
# 1162       None        NaN
# 1157       None        NaN
# 1126       None        NaN
# 1097       None        NaN
# 1106       None        NaN
# 1101       None        NaN
# 1121       None        NaN
# 1151       None        NaN
# 1146       None        NaN
# 1115       None        NaN
# 1111       None        NaN
# 558        None        NaN
# 550        None        NaN

# %% [markdown]
# # Dataframe converter

# %%
check_df = data_process(r'C:\Users\USER\Desktop\Final_Project\Data\Masekhet_er.json')

# %%
check_df
# Out:
#          text                                    url  \
# 0         m)y  bablex.php?coord=7100301002108&word=0
# 15517     $n)  bablex.php?coord=7100301002108&word=1
# 15516     gby  bablex.php?coord=7100301002108&word=2
# 15515  "swkh"  bablex.php?coord=7100301002108&word=3
# 15513    dtny  bablex.php?coord=7100301002108&word=4
# ...       ...                                    ...
# 293     )yhw;  bablex.php?coord=7100301105151&word=5
# 292        my  bablex.php?coord=7100301105151&word=6
# 291        l)  bablex.php?coord=7100301105151&word=7
# 290       )sr  bablex.php?coord=7100301105151&word=8
# 289    (lyhw;  bablex.php?coord=7100301105151&word=9
#
#                                                lexicon_0   lexicon_1  \
# 0                                         \n\n\nm)y P01         None
# 15517                                   \n\n\n$ny verb G        None
# 15516                     \n\n\ngby p01 = gby p --> gb p        None
# 15515  there is no data for this word, it may be unde...        None
# 15513                         \n\n\nd_ c = d_ c --> dy c  tny verb G
# ...                                                  ...         ...
# 293                                      \n\n\n)yhw P01         None
# 292                                          \n\n\nmy c         None
# 291                                          \n\n\nl) a         None
# 290                                     \n\n\n)sr verb G        None
# 289                                        \n\n\n(l p02         None
#
#       lexicon_2 lexicon_3  lexicon_4 text_transformed
# 0          None      None        NaN              מאי
# 15517      None      None        NaN              שנא
# 15516      None      None        NaN              גבי
# 15515      None      None        NaN             סוכה
# 15513      None      None        NaN             דתני
# ...         ...       ...        ...              ...
# 293        None      None        NaN            איהו;
# 292        None      None        NaN               מי
# 291        None      None        NaN               לא
# 290        None      None        NaN              אסר
# 289        None      None        NaN           עליהו;
#
# [15518 rows x 8 columns]

# %%
check_df = check_df.drop(['lexicon_4'], axis=1)

# %%
check_df
# Out:
#          text                                    url  \
# 0         m)y  bablex.php?coord=7100301002108&word=0
# 15517     $n)  bablex.php?coord=7100301002108&word=1
# 15516     gby  bablex.php?coord=7100301002108&word=2
# 15515  "swkh"  bablex.php?coord=7100301002108&word=3
# 15513    dtny  bablex.php?coord=7100301002108&word=4
# ...       ...                                    ...
# 293     )yhw;  bablex.php?coord=7100301105151&word=5
# 292        my  bablex.php?coord=7100301105151&word=6
# 291        l)  bablex.php?coord=7100301105151&word=7
# 290       )sr  bablex.php?coord=7100301105151&word=8
# 289    (lyhw;  bablex.php?coord=7100301105151&word=9
#
#                                                lexicon_0   lexicon_1  \
# 0                                         \n\n\nm)y P01         None
# 15517                                   \n\n\n$ny verb G        None
# 15516                     \n\n\ngby p01 = gby p --> gb p        None
# 15515  there is no data for this word, it may be unde...        None
# 15513                         \n\n\nd_ c = d_ c --> dy c  tny verb G
# ...                                                  ...         ...
# 293                                      \n\n\n)yhw P01         None
# 292                                          \n\n\nmy c         None
# 291                                          \n\n\nl) a         None
# 290                                     \n\n\n)sr verb G        None
# 289                                        \n\n\n(l p02         None
#
#       lexicon_2 lexicon_3 text_transformed
# 0          None      None              מאי
# 15517      None      None              שנא
# 15516      None      None              גבי
# 15515      None      None             סוכה
# 15513      None      None             דתני
# ...         ...       ...              ...
# 293        None      None            איהו;
# 292        None      None               מי
# 291        None      None               לא
# 290        None      None              אסר
# 289        None      None           עליהו;
#
# [15518 rows x 7 columns]
